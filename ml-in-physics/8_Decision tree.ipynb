# %%
# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
import matplotlib.pyplot as plt

# %%
# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# %%
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
#plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="depth=5", linewidth=2)
plt.xlabel("x")
plt.ylabel("$f(x)$")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
regr_3 = RandomForestRegressor(max_depth=5)
regr_3.fit(X, y)
regr_4 = AdaBoostRegressor()
regr_4.fit(X, y)

# Predict
#X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_3 = regr_3.predict(X_test)



# Predict
#X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_4 = regr_4.predict(X_test)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.plot(X_test, y_3, color="cornflowerblue",
         label="Randomforest", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()

# %%
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.plot(X_test, y_4, color="cornflowerblue",
         label="AdaBoost", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
