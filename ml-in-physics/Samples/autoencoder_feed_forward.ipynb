# %%
# minimalist (weird) autoencoder
# feedforward

import numpy as np
import keras
from keras.datasets import mnist
from keras.models import Sequential, Model
from keras.layers import Dense, Input
from keras import optimizers
from keras.optimizers import Adam
from keras.preprocessing import image

(x_train, y_train), (x_test, y_test) = mnist.load_data()
train_x = x_train.reshape(60000, 784) / 255
val_x = x_test.reshape(10000, 784) / 255

# Feed forward encoder
autoencoder = Sequential()
autoencoder.add(Dense(512,  activation='elu', input_shape=(784,)))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(10,    activation='linear', name="bottleneck"))
autoencoder.add(Dense(128,  activation='elu'))
autoencoder.add(Dense(512,  activation='elu'))
autoencoder.add(Dense(784,  activation='sigmoid'))
autoencoder.compile(loss='mean_squared_error', optimizer = Adam())

trained_model = autoencoder.fit(train_x, train_x, batch_size=1024, epochs=10, verbose=1, validation_data=(val_x, val_x))
encoder = Model(autoencoder.input, autoencoder.get_layer('bottleneck').output)
encoded_data = encoder.predict(train_x)  # bottleneck representation
decoded_output = autoencoder.predict(train_x)        # reconstruction
encoding_dim = 10

# return the decoder
encoded_input = Input(shape=(encoding_dim,))
decoder = autoencoder.layers[-3](encoded_input)
decoder = autoencoder.layers[-2](decoder)
decoder = autoencoder.layers[-1](decoder)
decoder = Model(encoded_input, decoder)


encoder.summary()
decoder.summary()
# Out:
# Epoch 1/10
# 59/59 [==============================] - 2s 32ms/step - loss: 0.0749 - val_loss: 0.0495
# Epoch 2/10
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0422 - val_loss: 0.0354
# Epoch 3/10
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0323 - val_loss: 0.0287
# Epoch 4/10
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0276 - val_loss: 0.0258
# Epoch 5/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0253 - val_loss: 0.0239
# Epoch 6/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0236 - val_loss: 0.0226
# Epoch 7/10
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0224 - val_loss: 0.0215
# Epoch 8/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0214 - val_loss: 0.0207
# Epoch 9/10
# 59/59 [==============================] - 2s 27ms/step - loss: 0.0206 - val_loss: 0.0199
# Epoch 10/10
# 59/59 [==============================] - 2s 31ms/step - loss: 0.0199 - val_loss: 0.0193
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2fbef76a5fed> in <module>
#      39
#      40 # if the img.png is not one of the MNIST dataset that the model was trained on, the error will be very high.
# ---> 41 img = image.load_img("./img.png", target_size=(28, 28), color_mode = "grayscale")
#      42 input_img = image.img_to_array(img)
#      43 inputs = input_img.reshape(1,784)
#
# C:\ProgramData\Miniconda3\envs\MLinPhysics38\lib\site-packages\tensorflow\python\keras\preprocessing\image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     298       ValueError: if interpolation method is not supported.
#     299   """
# --> 300   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
#     301                         target_size=target_size, interpolation=interpolation)
#     302
#
# C:\ProgramData\Miniconda3\envs\MLinPhysics38\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# FileNotFoundError: [Errno 2] No such file or directory: './img.png'
